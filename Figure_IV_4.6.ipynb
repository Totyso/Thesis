# %%
# %store -r EWMA
# %store -r AGARCH

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
EWMA = pd.Series(EWMA)
AGARCH = pd.Series(AGARCH)
EWMA.plot(grid=True, label='EWMA', legend=True)
AGARCH.plot(grid=True, label='AGARCH', legend=True);
