# %%
# %store -r SP
# %store -r SP_2
# %store -r Returns

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
SP_series = pd.Series(SP['Rtn'])
AGARCH_series = pd.Series(Returns['AGARCH Rtn'])
AGARCH_series.plot(grid=True, label='AGARCH', legend=True, color='blue', figsize=(15,5))
SP_series.plot(grid=True, label='Return', legend=True, color='red');
